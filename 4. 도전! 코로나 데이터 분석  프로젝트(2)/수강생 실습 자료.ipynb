# %% [markdown]
# # 도전! 코로나 데이터 분석 프로젝트

# %%
# 한글 출력을 도와주는 코드입니다 (1)
# (이 부분은 수정하지 말고 실행하세요!)
import matplotlib.font_manager as fm
fm._rebuild()

# %%
# 한글 출력을 도와주는 코드입니다 (2)
# (이 부분은 수정하지 말고 실행하세요!)
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')
sns.set(font='NanumGothic',
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# %% [markdown]
# # 실습

# %%
# 이 셀부터 실습을 시작하세요
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
world_corona = pd.read_csv("world_corona_201104.csv")

# %%
world_corona.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2019-12-31          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-01          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-02          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
world_corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53987 entries, 0 to 53986
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            53987 non-null  object
#  1   continent                           53987 non-null  object
#  2   location                            53987 non-null  object
#  3   date                                53987 non-null  object
#  4   total_cases                         50389 non-null  float64
#  5   new_cases                           53311 non-null  float64
#  6   new_cases_smoothed                  52516 non-null  float64
#  7   total_deaths                        41305 non-null  float64
#  8   new_deaths                          53311 non-null  float64
#  9   new_deaths_smoothed                 52516 non-null  float64
#  10  total_cases_per_million             50389 non-null  float64
# ...

# %%
world_corona['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4          Asia
#           ...
# 53982    Africa
# 53983    Africa
# 53984    Africa
# 53985    Africa
# 53986    Africa
# Name: continent, Length: 53987, dtype: object

# %%
world_corona['location']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 53982       Zimbabwe
# 53983       Zimbabwe
# 53984       Zimbabwe
# 53985       Zimbabwe
# 53986       Zimbabwe
# Name: location, Length: 53987, dtype: object

# %%
import matplotlib.font_manager as fm
fm._rebuild()

# %%
world_corona['location'].value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="location", data=world_corona, palette="Set2")

# %%
len(set(world_corona['location']))
# Out:
# 213

# %%
a = len(set(world_corona['new_cases']))

# %% [markdown]
# temp

# %%
len(set(world_corona['date']=='2020-10-30'))
# Out:
# 2

# %%
world_corona['date']=='2020-10-30'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53982    False
# 53983    False
# 53984    False
# 53985    False
# 53986    False
# Name: date, Length: 53987, dtype: bool

# %%
len(set([world_corona['date']=='2020-10-30'] and world_corona['new_cases']))
# Out:
# 5460

# %%
a = [world_corona['continent']=='Europe']

# %%
a and world_corona['location']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 53982       Zimbabwe
# 53983       Zimbabwe
# 53984       Zimbabwe
# 53985       Zimbabwe
# 53986       Zimbabwe
# Name: location, Length: 53987, dtype: object

# %%
world_corona['location']=='Japan'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53982    False
# 53983    False
# 53984    False
# 53985    False
# 53986    False
# Name: location, Length: 53987, dtype: bool

# %%
len(world_corona[(world_corona['new_cases'] > 0) & (world_corona['date']=='2020-10-30')])
# Out:
# 157

# %%
len(world_corona[(world_corona['location'] == 'Japan') & (world_corona['new_cases']> 0)])
# Out:
# 268

# %%
[world_corona['location'] if world_corona['gdp_per_capita'] >= 116935.6]
# Out:
#   File "<ipython-input-119-b59a3179ad89>", line 1
#     [world_corona['location'] if world_corona['gdp_per_capita'] >= 116935.6]
#                                                                            ^
# SyntaxError: invalid syntax

# %%
world_corona[world_corona['gdp_per_capita']== 116935.6]
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 39934      QAT      Asia    Qatar  2019-12-31          NaN        0.0
# 39935      QAT      Asia    Qatar  2020-01-01          NaN        0.0
# 39936      QAT      Asia    Qatar  2020-01-02          NaN        0.0
# 39937      QAT      Asia    Qatar  2020-01-03          NaN        0.0
# 39938      QAT      Asia    Qatar  2020-01-04          NaN        0.0
# ...        ...       ...      ...         ...          ...        ...
# 40239      QAT      Asia    Qatar  2020-10-31     132343.0      193.0
# 40240      QAT      Asia    Qatar  2020-11-01     132556.0      213.0
# 40241      QAT      Asia    Qatar  2020-11-02     132720.0      164.0
# 40242      QAT      Asia    Qatar  2020-11-03     132917.0      197.0
# 40243      QAT      Asia    Qatar  2020-11-04     133143.0      226.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
seoul_df = pd.read_csv("seoul_df.csv")

# %%
seoul_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5748 entries, 0 to 5747
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      5748 non-null   int64
#  1   확진달     5748 non-null   int64
#  2   확진일     5748 non-null   int64
#  3   환자번호    5748 non-null   int64
#  4   국적      0 non-null      float64
#  5   환자정보    0 non-null      float64
#  6   지역      5748 non-null   object
#  7   여행력     458 non-null    object
#  8   접촉력     5748 non-null   object
#  9   조치사항    0 non-null      float64
#  10  상태      5357 non-null   object
#  11  이동경로    5520 non-null   object
#  12  등록일     5748 non-null   object
#  13  수정일     5748 non-null   object
#  14  노출여부    5748 non-null   object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 673.7+ KB

# %%
seoul_df['접촉력']
# Out:
# 0        감염경로 조사중
# 1       강남서초 지인모임
# 2       기타 확진자 접촉
# 3        감염경로 조사중
# 4       기타 확진자 접촉
#           ...
# 5743        #5 접촉
# 5744        해외 접촉
# 5745        #3 접촉
# 5746        해외 접촉
# 5747        해외 접촉
# Name: 접촉력, Length: 5748, dtype: object

# %%
max(seoul_df['접촉력'])
# Out:
# '확인중'

# %%
seoul_df[seoul_df['접촉력']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-9175b0d95657> in <module>
# ----> 1 seoul_df[seoul_df['접촉력']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ...

# %%
seoul_df['접촉력'].value_counts().plot(kind='bar')
# Out:
# C:\Users\pje07\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pje07\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 53440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pje07\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pje07\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pje07\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
soeul_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-ee973629e4c4> in <module>
# ----> 1 soeul_df
#
# NameError: name 'soeul_df' is not defined

# %%
seoul_df
# Out:
#         연번  확진달  확진일   환자번호  국적  환자정보   지역     여행력        접촉력  조치사항   상태  \
# 0     5748   10   21  25530 NaN   NaN  양천구     NaN   감염경로 조사중   NaN  NaN
# 1     5747   10   21  25528 NaN   NaN  강동구     NaN  강남서초 지인모임   NaN  NaN
# 2     5746   10   21  25525 NaN   NaN  강남구     NaN  기타 확진자 접촉   NaN  NaN
# 3     5745   10   21  25517 NaN   NaN  관악구     NaN   감염경로 조사중   NaN  NaN
# 4     5744   10   21  25504 NaN   NaN  관악구     NaN  기타 확진자 접촉   NaN  NaN
# ...    ...  ...  ...    ...  ..   ...  ...     ...        ...   ...  ...
# 5743     5    1   31      9 NaN   NaN  성북구     NaN      #5 접촉   NaN   퇴원
# 5744     4    1   30      7 NaN   NaN  마포구  중국 우한시      해외 접촉   NaN   퇴원
# 5745     3    1   30      6 NaN   NaN  종로구     NaN      #3 접촉   NaN   퇴원
# 5746     2    1   30      5 NaN   NaN  중랑구  중국 우한시      해외 접촉   NaN   퇴원
# 5747     1    1   24      2 NaN   NaN  강서구  중국 우한시      해외 접촉   NaN   퇴원
#
#               이동경로               등록일               수정일 노출여부
# ...

# %%
seoul_df['접촉력']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-9175b0d95657> in <module>
# ----> 1 seoul_df[seoul_df['접촉력']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ...

# %%
seoul_df['접촉력'].unique()
# Out:
# array(['감염경로 조사중', '강남서초 지인모임', '기타 확진자 접촉', '관악구 삼모스포렉스Ⅱ',
#        '도봉구 예마루데이케어센터', '도봉구 다나병원', '강남구 CJ텔레닉스', '해외 유입', '타시도 확진자 접촉',
#        '송파구 잠언의료기', '강남구 CJ텔레닉스 관련', '강동구 행복데이케어센터', '중랑구 이마트 상봉점',
#        '해외 접촉 추정', '영등포구 방문판매업체 관련', '중구 소재 콜센터', '동작구 가족관련',
#        '서대문구 소재 장례식장', '관악구 식당관련', '영등포구 소모임', '송파구 서민국수', '중구 소재 빌딩 관련',
#        '마포구 서울디자인 고등학교', '타시도 확진자 접촉(강원강릉시지인모임)', '강남승광빌딩 관련',
#        '관악구 사랑나무 어린이집', '관악구 큰믿음유신감리교회', '동대문구 성경모임(발산대우주어린이집)',
#        '강북구 북서울 꿈의교회', '강남구 소재 대우디오빌플러스', '영등포구 LG트윈타워', '부산시 방문주사 관련',
#        '서초구 소재 카페 관련', '관악구 지인모임', '동작구 부동산회사', '관악구 휘트니스 관련', '강남구 삼성화재',
#        '양천구 양천경찰서', '서초구 LG 유플러스', '고양시부부관련', '관악구 가족 관련', '관악구 식당 관련',
#        '고양시부부관련(마포구어린이집&서초구우체국)', '관악구가족 관련(가가호호데이케어센터)', '관악구 삼모스포렉스',
#        '신도림 역사 관련', '강남구 디와이디벨로먼트', '동대문구 성경모임', '송파구 우리교회', '중랑구 서울의료원',
#        '종로구 서울대병원', '성동구 덕수고 야구부', '프로그래머 지인모임', '강남구 신도벤처타워',
#        '강남구 K보건산업', '건축설명회', '종로구청 관련', '강남구 통신판매업', '도봉구 소재 아파트 관련',
# ...

# %%
seoul_df.drop(seoul_df['접촉력']=='확인중')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-6237076be973> in <module>
# ----> 1 seoul_df.drop(seoul_df['접촉력']=='확인중')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
seoul_df['접촉력'].value_counts()
# Out:
# 기타 확진자 접촉          818
# 성북구 사랑제일교회 관련      641
# 확인 중               586
# 해외 접촉 추정           415
# 감염경로 조사중           373
#                   ...
# 경찰병원관련               1
# 한양대병원                1
# 고양시 반석교회(케네디상가)      1
# 강남구 CJ텔레닉스           1
# 신천지대구교회 관련           1
# Name: 접촉력, Length: 295, dtype: int64

# %%
seoul_df['지역'].value_counts()
# Out:
# 관악구     452
# 송파구     361
# 성북구     344
# 타시도     331
# 노원구     323
# 강남구     296
# 강서구     295
# 은평구     259
# 동작구     254
# 도봉구     223
# 서초구     210
# 중랑구     202
# 영등포구    200
# 강동구     199
# 구로구     193
# 양천구     186
# 마포구     180
# 동대문구    172
# 강북구     156
# 용산구     140
# 광진구     136
# 서대문구    135
# 성동구     130
# 기타      117
# 금천구      96
# 종로구      94
# 중구       64
# Name: 지역, dtype: int64

# %%
(452/5748) * 100
# Out:
# 7.8636047320807245

# %%
seoul_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5748 entries, 0 to 5747
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      5748 non-null   int64
#  1   확진달     5748 non-null   int64
#  2   확진일     5748 non-null   int64
#  3   환자번호    5748 non-null   int64
#  4   국적      0 non-null      float64
#  5   환자정보    0 non-null      float64
#  6   지역      5748 non-null   object
#  7   여행력     458 non-null    object
#  8   접촉력     5748 non-null   object
#  9   조치사항    0 non-null      float64
#  10  상태      5357 non-null   object
#  11  이동경로    5520 non-null   object
#  12  등록일     5748 non-null   object
#  13  수정일     5748 non-null   object
#  14  노출여부    5748 non-null   object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 673.7+ KB

# %%
seoul_df['확진달']
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 5743     1
# 5744     1
# 5745     1
# 5746     1
# 5747     1
# Name: 확진달, Length: 5748, dtype: int64

# %%
seoul_df['확진달'].value_counts()
# Out:
# 8     2416
# 9     1304
# 6      460
# 10     425
# 3      391
# 7      281
# 5      228
# 4      156
# 2       80
# 1        7
# Name: 확진달, dtype: int64

# %%
world_corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53987 entries, 0 to 53986
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            53987 non-null  object
#  1   continent                           53987 non-null  object
#  2   location                            53987 non-null  object
#  3   date                                53987 non-null  object
#  4   total_cases                         50389 non-null  float64
#  5   new_cases                           53311 non-null  float64
#  6   new_cases_smoothed                  52516 non-null  float64
#  7   total_deaths                        41305 non-null  float64
#  8   new_deaths                          53311 non-null  float64
#  9   new_deaths_smoothed                 52516 non-null  float64
#  10  total_cases_per_million             50389 non-null  float64
# ...

# %%
world_corona['total_deaths'].value_counts()
# Out:
# 1.0        2986
# 2.0        1213
# 3.0        1058
# 7.0         871
# 10.0        762
#            ...
# 4480.0        1
# 19649.0       1
# 2233.0        1
# 35203.0       1
# 13354.0       1
# Name: total_deaths, Length: 6943, dtype: int64

# %%
world_corona.groupby('total_deaths').sum()
# Out:
#               total_cases  new_cases  new_cases_smoothed  new_deaths  \
# total_deaths
# 1.0              425585.0    17907.0           13750.274       155.0
# 2.0              238318.0    15246.0           12474.600       165.0
# 3.0              225414.0    13395.0           10265.457       172.0
# 4.0              186558.0    12499.0            9975.140       157.0
# 5.0              281382.0    15135.0           11475.437       165.0
# ...                   ...        ...                 ...         ...
# 229708.0        9047427.0   101273.0           79108.286      1040.0
# 230556.0        9126361.0    78934.0           78519.429       848.0
# 230996.0        9207362.0    81001.0           81599.571       440.0
# 231551.0        9291245.0    83883.0           83817.286       555.0
# 232627.0        9383979.0    92734.0           86332.286      1076.0
#
#               new_deaths_smoothed  total_cases_per_million  \
# total_deaths
# ...

# %%
sum(world_corona['total_deaths'].value_counts())
# Out:
# 41305

# %%
world_corona[world_corona['location']=='French Polynesia']
# Out:
#       iso_code continent          location        date  total_cases  \
# 17788      PYF   Oceania  French Polynesia  2020-03-19          3.0
# 17789      PYF   Oceania  French Polynesia  2020-03-20          3.0
# 17790      PYF   Oceania  French Polynesia  2020-03-21         15.0
# 17791      PYF   Oceania  French Polynesia  2020-03-22         17.0
# 17792      PYF   Oceania  French Polynesia  2020-03-23         18.0
# ...        ...       ...               ...         ...          ...
# 18014      PYF   Oceania  French Polynesia  2020-10-31       7262.0
# 18015      PYF   Oceania  French Polynesia  2020-11-01       7262.0
# 18016      PYF   Oceania  French Polynesia  2020-11-02       7262.0
# 18017      PYF   Oceania  French Polynesia  2020-11-03       7262.0
# 18018      PYF   Oceania  French Polynesia  2020-11-04       8646.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 17788        3.0                 NaN           NaN         0.0
# ...

# %%
sum(world_corona['total_cases'].value_counts())
# Out:
# 50389

# %%
sum(world_corona['total_deaths'].value_counts())
# Out:
# 41305

# %%
(41305/50389)*100
# Out:
# 81.97225584949096

# %%
(50389/41305)*100
# Out:
# 121.99249485534438

# %%
(50389/41305)
# Out:
# 1.2199249485534438

# %%
world_corona[world_corona['location']=='Germany']
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 18797      DEU    Europe  Germany  2019-12-31          NaN        0.0
# 18798      DEU    Europe  Germany  2020-01-01          NaN        0.0
# 18799      DEU    Europe  Germany  2020-01-02          NaN        0.0
# 18800      DEU    Europe  Germany  2020-01-03          NaN        0.0
# 18801      DEU    Europe  Germany  2020-01-04          NaN        0.0
# ...        ...       ...      ...         ...          ...        ...
# 19102      DEU    Europe  Germany  2020-10-31     518753.0    19059.0
# 19103      DEU    Europe  Germany  2020-11-01     532930.0    14177.0
# 19104      DEU    Europe  Germany  2020-11-02     545027.0    12097.0
# 19105      DEU    Europe  Germany  2020-11-03     560379.0    15352.0
# 19106      DEU    Europe  Germany  2020-11-04     577593.0    17214.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [iso_code, continent, location, date, total_cases, new_cases, new_cases_smoothed, total_deaths, new_deaths, new_deaths_smoothed, total_cases_per_million, new_cases_per_million, new_cases_smoothed_per_million, total_deaths_per_million, new_deaths_per_million, new_deaths_smoothed_per_million, icu_patients, icu_patients_per_million, hosp_patients, hosp_patients_per_million, weekly_icu_admissions, weekly_icu_admissions_per_million, weekly_hosp_admissions, weekly_hosp_admissions_per_million, total_tests, new_tests, total_tests_per_thousand, new_tests_per_thousand, new_tests_smoothed, new_tests_smoothed_per_thousand, tests_per_case, positive_rate, tests_units, stringency_index, population, population_density, median_age, aged_65_older, aged_70_older, gdp_per_capita, extreme_poverty, cardiovasc_death_rate, diabetes_prevalence, female_smokers, male_smokers, handwashing_facilities, hospital_beds_per_thousand, life_expectancy, human_development_index]
# Index: []
#
# ...
